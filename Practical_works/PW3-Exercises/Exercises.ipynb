# %% [markdown]
# # Exercises on OOP

# %% [markdown]
# ## Operator Overloading

# %% [markdown]
# ### Exercise 1: Implement a complex number class. Overload the addition and subtraction operators to add and subtract two complex numbers.

# %%
class Complexnumber: 
    def __init__(self, real, imaginary):
        self.real = real
        self.imaginary = imaginary 

    def __add__(self, other):
        real = self.real + other.real
        imaginary = self.imaginary + other.imaginary
        return Complexnumber(real, imaginary)
    
    def __sub__(self, other):
        real = self.real - other.real
        imaginary = self.imaginary - other.imaginary 
        return Complexnumber(real, imaginary)
    
    def __str__(self):
        return f"{self.real} + {self.imaginary}i"

# %%
# Define two complex numbers to check if the addition and subtraction work correctly
c1 = Complexnumber(3, 4)
c2 = Complexnumber(1, 2)

# Test addition
result_add = c1 + c2
print(f"The sum of your two complex numbers is: {result_add}")

# Test Subtraction
result_sub = c1 - c2
print(f"The difference of your two complex numbers is: {result_sub}")
# Out:
# The sum of your two complex numbers is: 4 + 6i
# The difference of your two complex numbers is: 2 + 2i

# %% [markdown]
# What I learn from this exercise:
# - Class is an "Object" that is defined with operations called "Methods"; here we have addition __add__, subtraction __sub__, and display __str__.
# - We can also defined numbers through the class and perform the defined operations.
# - No overthinking on self, its a convention that helps with the format later on in the code.

# %% [markdown]
# ### Exercise 2: Create a class Person with name, age and gender as its attributes. Overload the > operator to compare two persons based on their age, such that p1 > p2 returns True if the age of p1 is greater than p2 and False otherwise.

# %%
class Person: 
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender 

    def __gt__(self, other):
        return self.age > other.age


    def __str__(self, other):
        if self > other:
            print(f"{self.name} is older than {other.name} of {self.age - other.age} years")
        else:
            print(f"{other.name} is other than {self.name} of {other.age - self.age} years")

# %%
person1 = Person("John", 30, "Male")
person2 = Person("Alice", 25, "Female")

person2.__str__(person1) # equivalent to person1 > person2
# Out:
# John is other than Alice of 5 years

# %% [markdown]
# ### Exercise 3: Create a class Vector that represents a vector in space, with x, y, and z as its attributes. Overload the * operator to return the dot product of two vectors, such that vector1 * vector2 returns the dot product of the two input vectors.

# %%
class Vector: 
    def __init__(self, x, y, z):
        self.x = x
        self.y = y 
        self.z = z
    
    def __mul__(self, other):
        dot_product = self.x * other.x + self.y * other.y + self.z * other.z
        return dot_product

# %%
vector1 = Vector(1, 2, 3)
vector2 = Vector(4, 5, 6)

scalar_product = vector1.__mul__(vector2) # equivalent to vector1 * vector2
print(f"The scalar product of the two vectors is: {scalar_product}")
# Out:
# The scalar product of the two vectors is: 32

# %% [markdown]
# What I learned:
# - When i define a sequence of operations I can define a name like dot_product that takes the information of the result of the operation.

# %% [markdown]
# ### Exercise 4: Overload all comparison operators (<, >, ==, !=, >=, <=) for a Circle class based on radius.

# %%
class Circle: 

    def __init__(self, radius):
        self.radius = radius 

    def __lt__(self, other): # less than operator
        return self.radius < other.radius 

    def __gt__(self, other): # greater than operator
        return self.radius > other.radius
    
    def __eq__(self, other): # equal to operator
        return self.radius == other.radius
    
    def __ne__(self, other): # not equal to operator
        return self.radius != other.radius
    
    def __le__(self, other): # less than or equal to operator
        return self.radius <= other.radius 
    
    def __ge__(self, other): # greater than or equal to operator    
        return self.radius >= other.radius

# %%
Circle1 = Circle(5)
Circle2 = Circle(10)
Circle3 = Circle(2)

# %%
print (Circle1 < Circle2) # True
print (Circle1 > Circle3) # True
print (Circle1 == Circle3) # False
print (Circle1 != Circle3) # True
print (Circle1 <= Circle2) # True
print (Circle1 >= Circle3) # True
# Out:
# True
# True
# False
# True
# True
# True

# %% [markdown]
# ### Exercise 5: Implement a 2D point class. Overload the comparison operators to compare two points based on their Euclidean distance from the origin.

# %%
class Point:

    def __init__(self, x, y):
        self.x = x
        self.y = y

    def Euclidean_distance(self):
       return (self.x ** 2 + self.y ** 2) ** 0.5

# %%
point1 = Point(3, 4)
point2 = Point(6, 8)
print(f"The Euclidean distance of point 1 from the origin is: {point1.Euclidean_distance()}")
print(f"The Euclidean distance of point 2 from the origin is: {point2.Euclidean_distance()}")  

if point1.Euclidean_distance() < point2.Euclidean_distance():
    print("Point 1 is closer to the origin than Point 2")
elif point1.Euclidean_distance() > point2.Euclidean_distance():
    print("Point 2 is closer to the origin than Point 1")
else:
    print("Both points are equidistant from the origin")
# Out:
# The Euclidean distance of point 1 from the origin is: 5.0
# The Euclidean distance of point 2 from the origin is: 10.0
# Point 1 is closer to the origin than Point 2

# %% [markdown]
# ### Exercise 6: Overload the multiplication operator for matrices
# (This I don't get the code, come back!!!)

# %%
class Matrices:

    def __init__(self, data):
        self.data = data
        self.rows = len(data)
        self.cols = len(data[0]) 

    def __mul__(self, other):
        if self.cols != other.rows:
            raise ValueError("Cannot Multiply the two matrices because the number of columns in the first matrix is not equal to the number of rows in the second matrix.")
        result = [[0 for _ in range(other.cols)] for _ in range(self.rows)]
        for i in range(self.rows):
            for j in range(other.cols):
                for k in range(self.cols):
                    result[i][j] += self.data[i][k] * other.data[k][j]
        return Matrices(result)

# %%
M1 = Matrices([[1, 2], [3, 4]])
M2 = Matrices([[5, 6], [7, 8]]) 
M3 = M1 * M2
print(f"The result of multiplying the two matrices is: {M3.data}")
# Out:
# The result of multiplying the two matrices is: [[19, 22], [43, 50]]

# %% [markdown]
# ## Inheritance exercises

# %% [markdown]
# ### Exercise 1: Create a class Vehicle that has a method drive that returns the string "Driving a vehicle". Create two subclasses, Car and Bicycle, that override this method to return "Driving a car" and "Riding a bicycle", respectively.

# %%
class Vehicle: 

    def __init__(self):
        pass

    def __drive__(self):
        print("Driving the vehicle...")

# %%
v1 = Vehicle()
v1.__drive__()
# Out:
# Driving the vehicle...

# %%
# Now we create the subclasses: Car and Bicycle. They inherit from the Vehicle class and override the __drive__ method to return "Driving the car" and "Riding the bicycle" respectively. 

class Car(Vehicle):

    def __drive__(self):
        print("Driving the car...")

class Bicycle(Vehicle):

    def __drive__(self):
        print("Riding the bicycle...")

# %%
c1 = Car()
c1.__drive__()

b1 = Bicycle()
b1.__drive__()
# Out:
# Driving the car...
# Riding the bicycle...

# %% [markdown]
# What I learn:
# - Inheritance says that Child classes inherit methods from Parent classes, and they can override the methods of parents classes.

# %% [markdown]
# ### Exercise 2:
# Create a class Person with attributes: name, age, address and method: introduce.
#
# Create a subclass Student of the class Person that has an attribute: field_of_study and a personalized method: introduce.
#
# Create another subclass Employee of the class Person that has an attribute: company and a personalized method: introduce.

# %%
class Person:

    def __init__(self, name, age, address):
        self.name = name
        self.age = age
        self.address = address

    def __introduyce__(self):
        print(f"Hello, my name is {self.name}, I am {self.age} years old and I live at {self.address}.")

# %%
person1 = Person("John", 30, "123 Main St")
person1.__introduyce__()
# Out:
# Hello, my name is John, I am 30 years old and I live at 123 Main St.

# %%
class Student(Person):

    def __init__(self, name, age, address, field_of_study):
        super().__init__(name, age, address)
        self.field_of_study = field_of_study

    def __introduce__(self):
        print(f"Hello, my name is {self.name}, I am {self.age} years old and I live at {self.address}. I study {self.field_of_study}.")

# %%
student1 = Student("John", 30, "123 Main St", "Computer Science")
student1.__introduce__()
# Out:
# Hello, my name is John, I am 30 years old and I live at 123 Main St. I study Computer Science.

# %%
class Employee(Person):

    def __init__(self, name, age, address, job_title):
        super().__init__(name, age, address)
        self.job_title = job_title

    def __introduce__(self):
        print(f"Hello, my name is {self.name}, I am {self.age} years old and I live at {self.address}. I work as a {self.job_title}.")

# %%
employee1 = Employee("Jean", 28, "Paris", "Software Engineer at Apple")
employee1.__introduce__()
# Out:
# Hello, my name is Jean, I am 28 years old and I live at Paris. I work as a Software Engineer at Apple.

# %% [markdown]
# ### Exercise 3:
#
# Define two classes, BankAccount and SavingsAccount:
#
# - BankAccount has attributes account_number and balance, and methods deposit and withdraw
# - SavingsAccount inherits from BankAccount and adds interest_rate attribute and add_interest method
# - Add a check_balance method to SavingsAccount
# - Add a transfer method to BankAccount that transfers money to a destination account (return False if insufficient balance, True otherwise)

# %%
class BankAccount:

    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def __deposit__(self, amount):
        self.balance += amount
        print(f"Deposited {amount}. New balance is {self.balance}.")

    def __withdraw__(self, amount):
        if amount > self.balance:
            print("Insufficient funds.")
        else:
            self.balance -= amount
            print(f"Withdrew {amount}. New balance is {self.balance}.")

    def __transfer__(self, amount, other_account):
        if amount > self.balance:
            print("Insufficient funds.")
        else:
            self.balance -= amount
            other_account.balance += amount 
            print(f"Transferred {amount} to account {other_account.account_number}. New balance is {self.balance}.")

# %%
BankAccount1 = BankAccount("123456789", 1000)
BankAccount1.__deposit__(500)
# Out:
# Deposited 500. New balance is 1500.

# %%
BankAccount1.__withdraw__(200)
# Out:
# Withdrew 200. New balance is 1300.

# %%
class SavingsAccount(BankAccount):

    def __init__(self, account_number, balance, interest_rate):
        super().__init__(account_number, balance)
        self.interest_rate = interest_rate

    def __add_interest__(self):
        interest = self.balance * self.interest_rate
        self.balance += interest
        print(f"Added interest of {interest}. New balance is {self.balance}.")

    def __Check_balance__(self):
        print(f"Current balance is {self.balance}.")

# %%
SavingsAccount1 = SavingsAccount("987654321", 2000, 0.05)
SavingsAccount1.__add_interest__()
# Out:
# Added interest of 100.0. New balance is 2100.0.

# %%
SavingsAccount1.__Check_balance__()
# Out:
# Current balance is 2100.0.

# %%
BankAccount2 = BankAccount("111111111", 500)
BankAccount1.__transfer__(300, BankAccount2)
# Out:
# Transferred 300 to account 111111111. New balance is 1000.

# %%
BankAccount1.__transfer__(2000, BankAccount2)
print(f"Bank Account 1 balance: {BankAccount1.balance}")
# Out:
# Insufficient funds.
# Bank Account 1 balance: 1000

# %% [markdown]
# # END OF EXERCISE
